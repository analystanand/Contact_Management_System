# %% [markdown]
# <a href="https://colab.research.google.com/github/analystanand/Contact_Management_System/blob/master/AlexNET.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
from torchvision import transforms
import time
from torchsummary import summary

# %%
class AlexNet(nn.Module):
    def __init__(self, num_classes=10):
        super(AlexNet, self).__init__()
        self.conv_base = nn.Sequential(
            nn.Conv2d(3, 96, kernel_size=8, stride=1, padding=1, bias=True),
            nn.ReLU(inplace=True),
            nn.Conv2d(96, 256, kernel_size=5, stride=1, padding=2, bias=True),
            nn.ReLU(inplace=True),
            nn.LocalResponseNorm(5),
            nn.MaxPool2d(kernel_size=3, stride=2),

            nn.Conv2d(256, 384, kernel_size=3, stride=1, padding=1),
            nn.ReLU(inplace=True),

            nn.Conv2d(384, 384, kernel_size=3, stride=1, padding=1),
            nn.ReLU(inplace=True),

            nn.Conv2d(384, 256, kernel_size=3, stride=1, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
        )
        self.fc_base = nn.Sequential(
            nn.Dropout(),
            nn.Linear(256 * 6 * 6, 4096),
            nn.ReLU(inplace=True),

            nn.Dropout(),
            nn.Linear(4096, 4096),
            nn.ReLU(inplace=True),

            nn.Linear(4096, num_classes),
        )

    def forward(self, x):
        x = self.conv_base(x)
        x = x.view(x.size(0), 256 * 6 * 6)
        x = self.fc_base(x)
        return x

# %%
# training data transformation
transform_train = transforms.Compose([
    # transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4821, 0.4465), (0.2470,0.2435,0.2616))])

# training data loader
train_set = torchvision.datasets.CIFAR10(root='./data',
                                         train=True,
                                         download=True,
                                         transform=transform_train,)

train_loader = torch.utils.data.DataLoader(dataset=train_set,
                                           batch_size=128,
                                           shuffle=True,
                                           num_workers=2)



# test data transformation
transform_test = transforms.Compose([transforms.ToTensor(),
                                     transforms.Normalize((0.4914, 0.4821, 0.4465), (0.2470, 0.2435,0.2616))])
# test data loader
testset = torchvision.datasets.CIFAR10(root='./data',
                                       train=False,
                                       download=True,
                                       transform=transform_test)

test_loader = torch.utils.data.DataLoader(dataset=testset,
                                          batch_size=128,
                                          shuffle=False,
                                          num_workers=2)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified

# %%
def train_model(model, loss_function, optimizer, data_loader):
    # set model to training mode
    model.train()

    current_loss = 0.0
    current_acc = 0

    # iterate over the training data
    for i, (inputs, labels) in enumerate(data_loader):
        # send the input/labels to the GPU
        inputs = inputs.to(device)
        labels = labels.to(device)

        # zero the parameter gradients
        optimizer.zero_grad()

        with torch.set_grad_enabled(True):
            # forward
            outputs = model(inputs)
            _, predictions = torch.max(outputs, 1)
            loss = loss_function(outputs, labels)

            # backward
            loss.backward()
            optimizer.step()

        # statistics
        current_loss += loss.item() * inputs.size(0)
        current_acc += torch.sum(predictions == labels.data)

    total_loss = current_loss / len(data_loader.dataset)
    total_acc = current_acc.double() / len(data_loader.dataset)

    print('Train Loss: {:.4f}; Accuracy: {:.4f}'.format(total_loss,
    total_acc))
    return total_loss, total_acc

# %%
def test_model(model, loss_function, data_loader):
    # set model in evaluation mode
    model.eval()

    current_loss = 0.0
    current_acc = 0

    # iterate over  the validation data
    for i, (inputs, labels) in enumerate(data_loader):
        # send the input/labels to the GPU
        inputs = inputs.to(device)
        labels = labels.to(device)

        # forward
        with torch.set_grad_enabled(False):
            outputs = model(inputs)
            _, predictions = torch.max(outputs, 1)
            loss = loss_function(outputs, labels)

        # statistics
        current_loss += loss.item() * inputs.size(0)
        current_acc += torch.sum(predictions == labels.data)

    total_loss = current_loss / len(data_loader.dataset)
    total_acc = current_acc.double() / len(data_loader.dataset)

    print('Test Loss: {:.4f}; Accuracy: {:.4f}'.format(total_loss,total_acc))

    return total_loss, total_acc

# %%
def plot_accuracy(test_accuracy: list,train_accuracy,model_name,ep):
    """Plot accuracy"""
    plt.figure()
    x =  range(1,ep+1)
    plt.plot(x,test_accuracy,color='b',label='Test')
    plt.plot(x,train_accuracy,color='r',label='Train')
    plt.title(model_name)
    # plt.xticks(
    #     [i for i in range(0, len(accuracy))],
    #     [i + 1 for i in range(0, len(accuracy))])
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    # plt.show()
    plt.legend()
    plt.savefig('{}.png'.format(model_name))

# %%
if __name__ == '__main__':
    model = AlexNet(num_classes=10)
    model_name = "AlexNET"
    start_time = time.time()
    print("Model:", model_name)
    # select gpu 0, if available# otherwise fallback to cpu
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
     # transfer the model to the GPU
    model = model.to(device)
    summary(model, (3, 32, 32))
   
    # loss function
    loss_function = nn.CrossEntropyLoss()
    # We'll optimize all parameters
    optimizer = optim.SGD(model.parameters(),lr=0.0005, momentum=0.9)

    EPOCHS = 50
    test_acc, train_acc = [], []  # collect accuracy for plotting
    for epoch in range(EPOCHS):
        print('Epoch {}/{}'.format(epoch + 1, EPOCHS))
        train_loss, train_accuracy = train_model(model, loss_function, optimizer, train_loader)
        test_loss, test_accuracy = test_model(model, loss_function, test_loader)
        train_acc.append(train_accuracy)
        test_acc.append(test_accuracy)
    endtime = time.time() - start_time
    print("Endtime %s seconds", endtime)
    plot_accuracy(test_acc, train_acc, model_name, EPOCHS)
# Out:
# Model: AlexNET
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 96, 27, 27]          18,528
#               ReLU-2           [-1, 96, 27, 27]               0
#             Conv2d-3          [-1, 256, 27, 27]         614,656
#               ReLU-4          [-1, 256, 27, 27]               0
#  LocalResponseNorm-5          [-1, 256, 27, 27]               0
#          MaxPool2d-6          [-1, 256, 13, 13]               0
#             Conv2d-7          [-1, 384, 13, 13]         885,120
#               ReLU-8          [-1, 384, 13, 13]               0
#             Conv2d-9          [-1, 384, 13, 13]       1,327,488
#              ReLU-10          [-1, 384, 13, 13]               0
#            Conv2d-11          [-1, 256, 13, 13]         884,992
#              ReLU-12          [-1, 256, 13, 13]               0
#         MaxPool2d-13            [-1, 256, 6, 6]               0
#           Dropout-14                 [-1, 9216]               0
#            Linear-15                 [-1, 4096]      37,752,832
#              ReLU-16                 [-1, 4096]               0
#           Dropout-17                 [-1, 4096]               0
#            Linear-18                 [-1, 4096]      16,781,312
#              ReLU-19                 [-1, 4096]               0
#            Linear-20                   [-1, 10]          40,970
# ================================================================
# Total params: 58,305,898
# Trainable params: 58,305,898
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 8.61
# Params size (MB): 222.42
# Estimated Total Size (MB): 231.04
# ----------------------------------------------------------------
# Epoch 1/50
# Train Loss: 2.3024; Accuracy: 0.1073
# Test Loss: 2.3021; Accuracy: 0.1155
# Epoch 2/50
# Train Loss: 2.3020; Accuracy: 0.1059
# Test Loss: 2.3014; Accuracy: 0.1224
# Epoch 3/50
# Train Loss: 2.3011; Accuracy: 0.1125
# Test Loss: 2.3000; Accuracy: 0.1433
# Epoch 4/50
# Train Loss: 2.2984; Accuracy: 0.1190
# Test Loss: 2.2940; Accuracy: 0.1084
# Epoch 5/50
# Train Loss: 2.2776; Accuracy: 0.1081
# Test Loss: 2.2468; Accuracy: 0.1399
# Epoch 6/50
# Train Loss: 2.2126; Accuracy: 0.1663
# Test Loss: 2.1671; Accuracy: 0.1851
# Epoch 7/50
# Train Loss: 2.1510; Accuracy: 0.1993
# Test Loss: 2.1210; Accuracy: 0.2160
# Epoch 8/50
# Train Loss: 2.0877; Accuracy: 0.2260
# Test Loss: 2.0318; Accuracy: 0.2270
# Epoch 9/50
# Train Loss: 1.9958; Accuracy: 0.2394
# Test Loss: 1.9515; Accuracy: 0.2497
# Epoch 10/50
# Train Loss: 1.9353; Accuracy: 0.2558
# Test Loss: 1.9102; Accuracy: 0.2672
# Epoch 11/50
# Train Loss: 1.8948; Accuracy: 0.2683
# Test Loss: 1.8765; Accuracy: 0.2752
# Epoch 12/50
# Train Loss: 1.8511; Accuracy: 0.2872
# Test Loss: 1.8437; Accuracy: 0.2795
# Epoch 13/50
# Train Loss: 1.7952; Accuracy: 0.3175
# Test Loss: 1.8399; Accuracy: 0.3047
# Epoch 14/50
# Train Loss: 1.7409; Accuracy: 0.3444
# Test Loss: 1.7892; Accuracy: 0.3271
# Epoch 15/50
# Train Loss: 1.6957; Accuracy: 0.3627
# Test Loss: 1.7854; Accuracy: 0.3470
# Epoch 16/50
# Train Loss: 1.6611; Accuracy: 0.3719
# Test Loss: 1.6392; Accuracy: 0.3847
# Epoch 17/50
# Train Loss: 1.6299; Accuracy: 0.3893
# Test Loss: 1.6761; Accuracy: 0.3700
# Epoch 18/50
# Train Loss: 1.6081; Accuracy: 0.3972
# Test Loss: 1.6059; Accuracy: 0.3964
# Epoch 19/50
# Train Loss: 1.5870; Accuracy: 0.4045
# Test Loss: 1.6765; Accuracy: 0.3890
# Epoch 20/50
# Train Loss: 1.5628; Accuracy: 0.4149
# Test Loss: 1.5579; Accuracy: 0.4200
# Epoch 21/50
# Train Loss: 1.5398; Accuracy: 0.4250
# Test Loss: 1.5585; Accuracy: 0.4212
# Epoch 22/50
# Train Loss: 1.5291; Accuracy: 0.4282
# Test Loss: 1.4982; Accuracy: 0.4354
# Epoch 23/50
# Train Loss: 1.5010; Accuracy: 0.4412
# Test Loss: 1.4722; Accuracy: 0.4521
# Epoch 24/50
# Train Loss: 1.4847; Accuracy: 0.4482
# Test Loss: 1.5297; Accuracy: 0.4438
# Epoch 25/50
# Train Loss: 1.4588; Accuracy: 0.4589
# Test Loss: 1.4598; Accuracy: 0.4599
# Epoch 26/50
# Train Loss: 1.4442; Accuracy: 0.4627
# Test Loss: 1.4223; Accuracy: 0.4729
# Epoch 27/50
# Train Loss: 1.4175; Accuracy: 0.4758
# Test Loss: 1.4034; Accuracy: 0.4797
# Epoch 28/50
# Train Loss: 1.4066; Accuracy: 0.4809
# Test Loss: 1.4135; Accuracy: 0.4832
# Epoch 29/50
# Train Loss: 1.3907; Accuracy: 0.4870
# Test Loss: 1.3616; Accuracy: 0.4997
# Epoch 30/50
# Train Loss: 1.3726; Accuracy: 0.4936
# Test Loss: 1.4327; Accuracy: 0.4855
# Epoch 31/50
# Train Loss: 1.3462; Accuracy: 0.5052
# Test Loss: 1.3322; Accuracy: 0.5100
# Epoch 32/50
# Train Loss: 1.3295; Accuracy: 0.5121
# Test Loss: 1.4628; Accuracy: 0.4817
# Epoch 33/50
# Train Loss: 1.3170; Accuracy: 0.5189
# Test Loss: 1.3426; Accuracy: 0.5146
# Epoch 34/50
# Train Loss: 1.3023; Accuracy: 0.5258
# Test Loss: 1.3229; Accuracy: 0.5187
# Epoch 35/50
# Train Loss: 1.2861; Accuracy: 0.5299
# Test Loss: 1.3785; Accuracy: 0.5095
# Epoch 36/50
# Train Loss: 1.2708; Accuracy: 0.5397
# Test Loss: 1.2990; Accuracy: 0.5310
# Epoch 37/50
# Train Loss: 1.2481; Accuracy: 0.5479
# Test Loss: 1.3256; Accuracy: 0.5268
# Epoch 38/50
# Train Loss: 1.2466; Accuracy: 0.5452
# Test Loss: 1.2804; Accuracy: 0.5273
# Epoch 39/50
# Train Loss: 1.2256; Accuracy: 0.5555
# Test Loss: 1.2962; Accuracy: 0.5309
# Epoch 40/50
# Train Loss: 1.2131; Accuracy: 0.5611
# Test Loss: 1.2077; Accuracy: 0.5648
# Epoch 41/50
# Train Loss: 1.1912; Accuracy: 0.5697
# Test Loss: 1.2135; Accuracy: 0.5651
# Epoch 42/50
# Train Loss: 1.1779; Accuracy: 0.5722
# Test Loss: 1.2128; Accuracy: 0.5635
# Epoch 43/50
# Train Loss: 1.1665; Accuracy: 0.5802
# Test Loss: 1.1961; Accuracy: 0.5701
# Epoch 44/50
# Train Loss: 1.1561; Accuracy: 0.5827
# Test Loss: 1.1841; Accuracy: 0.5734
# Epoch 45/50
# Train Loss: 1.1391; Accuracy: 0.5899
# Test Loss: 1.1354; Accuracy: 0.5892
# Epoch 46/50
# Train Loss: 1.1264; Accuracy: 0.5922
# Test Loss: 1.1369; Accuracy: 0.5896
# Epoch 47/50
# Train Loss: 1.1162; Accuracy: 0.5963
# Test Loss: 1.1138; Accuracy: 0.6039
# Epoch 48/50
# Train Loss: 1.0990; Accuracy: 0.6018
# Test Loss: 1.1008; Accuracy: 0.6017
# Epoch 49/50
# Train Loss: 1.0926; Accuracy: 0.6052
# Test Loss: 1.0660; Accuracy: 0.6162
# Epoch 50/50
# Train Loss: 1.0768; Accuracy: 0.6109
# Test Loss: 1.0813; Accuracy: 0.6124
# Endtime %s seconds 1580.0585746765137
